# %%
import kmds
from kmds.tagging.tag_types import DataRepresentationTags
from owlready2 import *
from kmds.utils.load_utils import *
from kmds.utils.path_utils import get_package_kb_path
KNOWLEDGE_BASE = "../data/kmds/sba_loans_kb.xml"
onto2 :Ontology = load_kb(KNOWLEDGE_BASE)
import pandas as pd
pd.options.display.max_colwidth = 600

# %% [markdown]
# ## SBA Loans: Data Exploration, Sourcing, Profiling and Cleaning

# %%
df_exp = load_exp_observations(onto2)
df_exp = df_exp.sort_values(by='finding_seq')
df_exp = df_exp.style.set_properties(**{'text-align': 'left'})
display(df_exp)

# %% [markdown]
# ## SBA Loans: Data Transformation (including Feature Engineering)

# %%
df_dr = load_data_rep_observations(onto2)

# %%
df_dr = df_dr.sort_values(by='finding_seq')
df_dr = df_dr.style.set_properties(**{'text-align': 'left'})
display(df_dr)

# %% [markdown]
# ## SBA Loans: Model Planning, Review and Refinement

# %%
df_mc = load_modelling_choice_observations(onto2)
df_mc = df_mc.sort_values(by='finding_seq')
df_mc = df_mc.style.set_properties(**{'text-align': 'left'})
display(df_mc)
